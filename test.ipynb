# %%
import torch
import torchvision
import utils
import numpy as np
import matplotlib.pyplot as plt

# %%
data, labels = utils.read_data('cifar-10-batches-py/data_batch_1')
augmented_data = utils.augment(data)
for i in range(3):
    plt.imshow(data[i].transpose(1, 2, 0))
    plt.show()
    plt.imshow(augmented_data[i].transpose(1, 2, 0))
    plt.show()

# %%
test = utils.gen_copies(data)

# %%
for i in range(4):
    plt.imshow(test[i].transpose(1, 2, 0))
    plt.show()
