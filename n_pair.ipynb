# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import utils
import models
from sklearn.svm import SVC, LinearSVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA, KernelPCA
from torchsummary import summary
import matplotlib.patches as mpatches
from matplotlib.cm import get_cmap

# %%
train_dataset = utils.dataset_with_indices(torchvision.datasets.FashionMNIST)(root='mnist', train=True, transform=torchvision.transforms.ToTensor())
test_dataset = utils.dataset_with_indices(torchvision.datasets.FashionMNIST)(root='mnist', train=False, transform=torchvision.transforms.ToTensor())
model = models.Network()

# %%
train_losses, val_accuracies_regular, val_accuracies_forward, training_time = utils.train(model, train_dataset, test_dataset, utils.supervised_n_tuple_loss, epochs=30, batch_size=10)
# Out:
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 1/30, training loss: -53.305756678471965, val accuracies regular: 0.8557, val accuracies forward: 0.8354
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 2/30, training loss: -64.62870961146801, val accuracies regular: 0.8716, val accuracies forward: 0.8567
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 3/30, training loss: -67.18974715340137, val accuracies regular: 0.8815, val accuracies forward: 0.8701
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 4/30, training loss: -69.03720481785139, val accuracies regular: 0.8856, val accuracies forward: 0.8801
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 5/30, training loss: -70.40875836515427, val accuracies regular: 0.8885, val accuracies forward: 0.8801
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 6/30, training loss: -71.11239828437567, val accuracies regular: 0.8921, val accuracies forward: 0.8865
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 7/30, training loss: -71.83411582541466, val accuracies regular: 0.8939, val accuracies forward: 0.8866
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 8/30, training loss: -72.36477746923765, val accuracies regular: 0.8957, val accuracies forward: 0.8858
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 9/30, training loss: -72.9095064064612, val accuracies regular: 0.8981, val accuracies forward: 0.8908
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 10/30, training loss: -73.57116560920079, val accuracies regular: 0.898, val accuracies forward: 0.8935
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 11/30, training loss: -74.00325378740827, val accuracies regular: 0.9001, val accuracies forward: 0.892
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 12/30, training loss: -74.5998224261999, val accuracies regular: 0.9022, val accuracies forward: 0.9003
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 13/30, training loss: -75.10658645673593, val accuracies regular: 0.9023, val accuracies forward: 0.8991
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 14/30, training loss: -75.3438965601921, val accuracies regular: 0.9029, val accuracies forward: 0.8979
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 15/30, training loss: -76.0364224960804, val accuracies regular: 0.9061, val accuracies forward: 0.8998
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 16/30, training loss: -75.85121020237605, val accuracies regular: 0.9047, val accuracies forward: 0.9001
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 17/30, training loss: -76.55375375262896, val accuracies regular: 0.9044, val accuracies forward: 0.9023
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 18/30, training loss: -76.98693959516412, val accuracies regular: 0.903, val accuracies forward: 0.8976
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 19/30, training loss: -77.01397063453992, val accuracies regular: 0.9062, val accuracies forward: 0.9054
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 20/30, training loss: -77.64102528146903, val accuracies regular: 0.9034, val accuracies forward: 0.9029
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 21/30, training loss: -78.19695102478316, val accuracies regular: 0.9067, val accuracies forward: 0.9041
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 22/30, training loss: -78.3610004089276, val accuracies regular: 0.9074, val accuracies forward: 0.9025
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 23/30, training loss: -78.53353462477526, val accuracies regular: 0.9081, val accuracies forward: 0.9031
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 24/30, training loss: -78.71738736510277, val accuracies regular: 0.9072, val accuracies forward: 0.9036
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 25/30, training loss: -79.0324190826416, val accuracies regular: 0.9076, val accuracies forward: 0.9091
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 26/30, training loss: -79.2462702630361, val accuracies regular: 0.9064, val accuracies forward: 0.9058
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 27/30, training loss: -79.3791959408919, val accuracies regular: 0.9061, val accuracies forward: 0.8983
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 28/30, training loss: -79.59849837811788, val accuracies regular: 0.9065, val accuracies forward: 0.9058
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 29/30, training loss: -80.02200218197703, val accuracies regular: 0.9064, val accuracies forward: 0.9066
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 30/30, training loss: -80.4075385158062, val accuracies regular: 0.9088, val accuracies forward: 0.9049
# Training time: 2733.9776639938354s

# %%
train_losses2, val_accuracies_regular2, val_accuracies_forward2, training_time2 = utils.train(model, train_dataset, test_dataset, utils.supervised_n_tuple_loss, epochs=30, batch_size=10)
# Out:
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 1/30, training loss: -80.34242750199635, val accuracies regular: 0.9076, val accuracies forward: 0.9099
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 2/30, training loss: -80.8513424138228, val accuracies regular: 0.9077, val accuracies forward: 0.9066
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 3/30, training loss: -81.16635092439255, val accuracies regular: 0.9076, val accuracies forward: 0.9061
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 4/30, training loss: -81.43858639192581, val accuracies regular: 0.9048, val accuracies forward: 0.9044
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 5/30, training loss: -81.31425211064021, val accuracies regular: 0.9063, val accuracies forward: 0.9086
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 6/30, training loss: -81.65783062156042, val accuracies regular: 0.9066, val accuracies forward: 0.9069
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 7/30, training loss: -81.73852514449756, val accuracies regular: 0.9045, val accuracies forward: 0.905
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 8/30, training loss: -81.8943467790087, val accuracies regular: 0.9074, val accuracies forward: 0.9084
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 9/30, training loss: -81.95288132985434, val accuracies regular: 0.9091, val accuracies forward: 0.9072
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 10/30, training loss: -82.25206079727411, val accuracies regular: 0.9086, val accuracies forward: 0.9061
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 11/30, training loss: -82.44411973849932, val accuracies regular: 0.9062, val accuracies forward: 0.9062
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 12/30, training loss: -82.53373873664935, val accuracies regular: 0.9068, val accuracies forward: 0.9037
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 13/30, training loss: -82.59804397249222, val accuracies regular: 0.9038, val accuracies forward: 0.9056
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 14/30, training loss: -82.97492224899928, val accuracies regular: 0.9045, val accuracies forward: 0.9066
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 15/30, training loss: -82.93693516167005, val accuracies regular: 0.9065, val accuracies forward: 0.906
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 16/30, training loss: -82.93303707965215, val accuracies regular: 0.9061, val accuracies forward: 0.9057
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 17/30, training loss: -83.34712339576086, val accuracies regular: 0.9067, val accuracies forward: 0.9072
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 18/30, training loss: -83.23181886514028, val accuracies regular: 0.9085, val accuracies forward: 0.9074
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 19/30, training loss: -83.44270465834936, val accuracies regular: 0.9058, val accuracies forward: 0.9067
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 20/30, training loss: -83.6216067293485, val accuracies regular: 0.9061, val accuracies forward: 0.9034
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 21/30, training loss: -83.67031037871043, val accuracies regular: 0.9075, val accuracies forward: 0.9089
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 22/30, training loss: -83.72233124669393, val accuracies regular: 0.9067, val accuracies forward: 0.908
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 23/30, training loss: -83.88971407047907, val accuracies regular: 0.9066, val accuracies forward: 0.9068
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 24/30, training loss: -83.95413200227419, val accuracies regular: 0.9051, val accuracies forward: 0.9063
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 25/30, training loss: -84.23154755767186, val accuracies regular: 0.9049, val accuracies forward: 0.9061
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 26/30, training loss: -84.1200186453263, val accuracies regular: 0.906, val accuracies forward: 0.9075
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 27/30, training loss: -84.33386386076609, val accuracies regular: 0.9059, val accuracies forward: 0.9024
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 28/30, training loss: -84.34442325615883, val accuracies regular: 0.9063, val accuracies forward: 0.9059
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 29/30, training loss: -84.39104611786206, val accuracies regular: 0.904, val accuracies forward: 0.9024
# Loss:   0%|          | 0/6000 [00:00<?, ?it/s]
# Epoch 30/30, training loss: -84.39519562848409, val accuracies regular: 0.9053, val accuracies forward: 0.9043
# Training time: 2457.6616389751434s

# %%
torch.save(model.state_dict(), 'trained_models/supervised_n_pair')

# %%
all_val_accuracies = val_accuracies_regular + val_accuracies_regular2
np.savetxt('data/n_pair_val_accuracies', np.array(all_val_accuracies), delimiter=',')

# %%
all_train_losses = train_losses + train_losses2
np.savetxt('data/n_pair_train_losses', np.array(all_train_losses), delimiter=',')

# %%
plt.plot(val_accuracies_regular + val_accuracies_regular2, marker='o', label='Test Loss')
plt.xlabel('Iteration Number')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(train_losses + train_losses2, marker='o', label='Training Loss')
plt.xlabel('Iteration Number')
plt.ylabel('Loss')
plt.show()

# %%
train_embedding, test_embedding = utils.embed_regular(model, train_dataset, test_dataset)

raw_train_embedding = train_dataset.data.reshape(train_dataset.data.shape[0], 28*28)
raw_test_embedding = test_dataset.data.reshape(test_dataset.data.shape[0], 28*28)

# %%
svm_train_embedding = LinearSVC(C=10.0).fit(train_embedding, train_dataset.targets)
svm_train_embedding.score(test_embedding, test_dataset.targets)
# Out:
# 0.8906

# %%
pca_embedding = PCA(n_components=2).fit(train_embedding)
pca_test_projection = pca_embedding.transform(test_embedding)

pca_raw = PCA(n_components=2).fit(raw_train_embedding)
pca_raw_projection = pca_raw.transform(raw_test_embedding)

# %%
fig, axs = plt.subplots(2, figsize=(6, 10))
ax1 = axs[0]
ax2 = axs[1]

# plot 1
ax1.scatter(pca_raw_projection[:,0], pca_raw_projection[:,1], c=test_dataset.targets, cmap='tab10', s=1)
ax1.set_xlabel('$x_1$')
ax1.set_ylabel('$x_2$')
ax1.set_title('PCA Projection of Raw Data')

# plot 2
ax2.set_title('PCA Projection of Embedded Data')
ax2.scatter(pca_test_projection[:,0], pca_test_projection[:,1], c=test_dataset.targets, cmap='tab10', s=1)
ax2.set_xlabel('$x_1$')
ax2.set_ylabel('$x_2$')

patches = []
num_classes = len(train_dataset.classes)
for i in range(num_classes):
    patches.append(mpatches.Patch(color=get_cmap('tab10')(i/(num_classes-1)), label=train_dataset.classes[i]))
plt.legend(handles=patches, loc='center', bbox_to_anchor=(0.5, -0.25), ncol=5)
plt.show()

# %%
lda_embedding = LinearDiscriminantAnalysis(n_components=2).fit(train_embedding, train_dataset.targets)
lda_test_projection = lda_embedding.transform(test_embedding)

lda_raw = LinearDiscriminantAnalysis(n_components=2).fit(raw_train_embedding, train_dataset.targets)
lda_raw_projection = lda_raw.transform(raw_test_embedding)

# %%
fig, axs = plt.subplots(2, figsize=(6, 10))
ax1 = axs[0]
ax2 = axs[1]

# plot 1
ax1.scatter(lda_raw_projection[:,0], lda_raw_projection[:,1], c=test_dataset.targets, cmap='tab10', s=1)
ax1.set_xlabel('$x_1$')
ax1.set_ylabel('$x_2$')
ax1.set_title('LDA Projection of Raw Data')

# plot 2
ax2.set_title('LDA Projection of Embedded Data')
ax2.scatter(lda_test_projection[:,0], lda_test_projection[:,1], c=test_dataset.targets, cmap='tab10', s=1)
ax2.set_xlabel('$x_1$')
ax2.set_ylabel('$x_2$')

patches = []
num_classes = len(train_dataset.classes)
for i in range(num_classes):
    patches.append(mpatches.Patch(color=get_cmap('tab10')(i/(num_classes-1)), label=train_dataset.classes[i]))
plt.legend(handles=patches, loc='center', bbox_to_anchor=(0.5, -0.25), ncol=5)
plt.show()
